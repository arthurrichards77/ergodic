# %%
import glob

# %%
file_list = glob.glob('run_*.json')

# %%
fn = file_list[0]

# %%
import json

# %%
with open(fn,'r') as f:
    data_dict = json.load(f)

# %%
data_dict
# Out:
# {'method': 'revisit',
#  'case': 'run_1723635087',
#  'wave_numbers': [[0, 0],
#   [0, 1],
#   [0, 2],
#   [0, 3],
#   [1, 0],
#   [1, 1],
#   [1, 2],
#   [1, 3],
#   [2, 0],
#   [2, 1],
#   [2, 2],
#   [2, 3],
#   [3, 0],
#   [3, 1],
#   [3, 2],
#   [3, 3]],
#  'pdf': 'gaussian',
#  'mesh': 'tri 8x8',
#  'num_moves': 16,
#  'num_binaries': 5152,
#  'time_limit': 300,
#  'solve_time': 148.46816039085388,
#  'objective': 0.009080590765222812,
#  'ergodic': 0.0005693584963645422}

# %%
import pandas

# %%
df = pandas.DataFrame(columns=[k for k in data_dict.keys()])

# %%
df
# Out:
# Empty DataFrame
# Columns: [method, case, wave_numbers, pdf, mesh, num_moves, num_binaries, time_limit, solve_time, objective, ergodic]
# Index: []

# %%
for fn in file_list:
    with open(fn,'r') as f:
        data_dict = json.load(f)
    df.loc[len(df)] = pandas.Series(data_dict)

# %%
df['wave_count'] = [len(w) for w in df.wave_numbers]

# %%
df.sort_values(['pdf','mesh','num_moves','method','wave_count'])
# Out:
#                       method            case
# 48         revisit-fix0-fix1  run_1723808383  \
# 45         revisit-fix0-fix1  run_1723806954
# 46         revisit-fix0-fix1  run_1723807060
# 47         revisit-fix0-fix1  run_1723807697
# 49         revisit-fix0-fix1  run_1723809330
# 50         revisit-fix0-fix1  run_1723810157
# 52         revisit-fix0-fix1  run_1723819170
# 53  revisit-fix0-fix1-spread  run_1723821643
# 44         revisit-fix0-fix1  run_1723806727
# 16                   revisit  run_1723800328
# 17                   revisit  run_1723800583
# 41         revisit-fix0-fix1  run_1723806205
# 39         revisit-fix0-fix1  run_1723805754
# 40         revisit-fix0-fix1  run_1723805849
# 38         revisit-fix0-fix1  run_1723805132
# 34              revisit-fix0  run_1723803236
# 33         revisit-fix0-fix1  run_1723803172
# 7                    revisit  run_1723645604
# 12                   revisit  run_1723652629
# 13                   revisit  run_1723799451
# 14                   revisit  run_1723799723
# 15                   revisit  run_1723799815
# 23                   revisit  run_1723801759
# 22              revisit-fix0  run_1723801682
# 21         revisit-fix0-fix1  run_1723801528
# 25         revisit-fix0-fix1  run_1723801933
# 24              revisit-fix1  run_1723801842
# 32         revisit-fix0-fix1  run_1723803018
# 6                        tsp  run_1723642380
# 36         revisit-fix0-fix1  run_1723803654
# 10                   revisit  run_1723648630
# 11                   revisit  run_1723649500
# 0                    revisit  run_1723635087
# 8                        tsp  run_1723647831
# 51         revisit-fix0-fix1  run_1723812079
# 54  revisit-fix0-fix1-spread  run_1723823767
# 3                    revisit  run_1723641690
# 2                        tsp  run_1723641628
# 35              revisit-fix0  run_1723803340
# 30         revisit-fix0-fix1  run_1723802605
# 4                    revisit  run_1723641880
# 18                   revisit  run_1723800819
# 28                   revisit  run_1723802327
# 19              revisit-fix0  run_1723801077
# 42         revisit-fix0-fix1  run_1723806260
# 43         revisit-fix0-fix1  run_1723806289
# 20         revisit-fix0-fix1  run_1723801384
# 26         revisit-fix0-fix1  run_1723802008
# 29         revisit-fix0-fix1  run_1723802478
# 27              revisit-fix1  run_1723802168
# 31         revisit-fix0-fix1  run_1723802715
# 5                        tsp  run_1723642190
# 37         revisit-fix0-fix1  run_1723804005
# 1                    revisit  run_1723639538
# 9                        tsp  run_1723648269
#
#                                          wave_numbers              pdf
# 48  [[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2...   bias-northeast  \
# 45  [[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2...   bias-northeast
# 46  [[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2...   bias-northeast
# 47  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...   bias-northeast
# 49  [[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2...   bias-northeast
# 50  [[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2...   bias-northeast
# 52  [[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2...   bias-northeast
# 53  [[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2...   bias-northeast
# 44  [[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2...       bias-right
# 16  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...    cosine-ridges
# 17  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...  cosine-ridges-2
# 41                   [[0, 0], [0, 1], [1, 0], [1, 1]]  cosine-ridges-2
# 39  [[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2...  cosine-ridges-2
# 40  [[0, 0], [0, 1], [0, 2], [0, 3], [0, 4], [1, 0...  cosine-ridges-2
# 38  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...  cosine-ridges-2
# 34  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 33  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 7   [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 12  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 13  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 14  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 15  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 23  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 22  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 21  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 25  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 24  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 32  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 6   [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 36  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 10  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 11  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 0   [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 8   [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...         gaussian
# 51  [[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2...     gaussian-mix
# 54  [[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2...     gaussian-mix
# 3   [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 2   [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 35  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 30  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 4   [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 18  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 28  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 19  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 42                   [[0, 0], [0, 1], [1, 0], [1, 1]]          uniform
# 43  [[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2...          uniform
# 20  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 26  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 29  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 27  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 31  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 5   [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 37  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 1   [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 9   [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
#
#                  mesh num_moves num_binaries time_limit  solve_time objective
# 48       square 15x15        30        25200        300  301.979932  0.055197  \
# 45         square 8x8        16         3584        300   83.248359  0.042958
# 46         square 8x8        24         5376        300  300.817937  0.010856
# 47         square 8x8        24         5376        300  300.385234   0.02724
# 49          tri 15x15        30        36960        300  302.700915  0.061686
# 50          tri 15x15        60        73920        600  606.032607  0.001439
# 52          tri 15x15        90       110880        600  612.025406  0.006651
# 53          tri 15x15        90       110880        600  608.363755  0.038545
# 44         square 8x8        16         3584        300  109.437355  0.048428
# 16         square 8x8        16         3584        300  128.361865   0.06382
# 17         square 8x8        16         3584        300    32.70274  0.066172
# 41         square 8x8        16         3584        300    3.766991  0.002087
# 39         square 8x8        16         3584        300   34.921739  0.056485
# 40         square 8x8        16         3584        300  196.829248  0.082853
# 38         square 8x8        24         5376        300  300.454803  0.064894
# 34         square 8x8        15         3360        300     4.90568  0.012567
# 33         square 8x8        15         3360        300      6.4648  0.012567
# 7          square 8x8        16         3584        300   29.252594  0.014991
# 12         square 8x8        16         3584        300   28.127865  0.014991
# 13         square 8x8        16         3584        300   28.124335  0.014991
# 14         square 8x8        16         3584        300   28.496358  0.014991
# 15         square 8x8        16         3584        300   31.204091  0.014991
# 23         square 8x8        16         3584        300   28.332871  0.014991
# 22         square 8x8        16         3584        300   33.372293  0.014991
# 21         square 8x8        16         3584        300   23.922762  0.014991
# 25         square 8x8        16         3584        300    24.16305  0.014991
# 24         square 8x8        16         3584        300   30.473071  0.014991
# 32         square 8x8        17         3808        300   82.781402  0.013111
# 6          square 8x8        18          352        300   300.08873  0.152763
# 36         square 8x8        24         5376        300   300.37682  0.010117
# 10         square 9x9        18         5184        300  124.871074  0.010217
# 11  square 9x9 + hole        18         5040        300   45.168894  0.013588
# 0             tri 8x8        16         5152        300   148.46816  0.009081
# 8             tri 8x8        18          450        300  301.879667  0.142704
# 51          tri 15x15        90       110880        600  608.080374   0.04014
# 54          tri 15x15        90       110880        600  610.130337  0.049384
# 3          square 6x6        12         1440        300    4.614976  0.029299
# 2          square 6x6        14          192        300    4.986134  0.181919
# 35         square 8x8        15         3360        300    85.04732  0.060953
# 30         square 8x8        15         3360        300   74.831635  0.060953
# 4          square 8x8        16         3584        300  108.727021  0.043949
# 18         square 8x8        16         3584        300   98.744452  0.043949
# 28         square 8x8        16         3584        300  105.399934  0.043949
# 19         square 8x8        16         3584        300   88.936969  0.043949
# 42         square 8x8        16         3584        300    9.747314       0.0
# 43         square 8x8        16         3584        300   63.351682  0.043093
# 20         square 8x8        16         3584        300   84.576104  0.043949
# 26         square 8x8        16         3584        300   88.233253  0.043949
# 29         square 8x8        16         3584        300   90.688772  0.043949
# 27         square 8x8        16         3584        300  119.515787  0.043949
# 31         square 8x8        17         3808        300  146.012283  0.043502
# 5          square 8x8        18          352        300  156.553507  0.156354
# 37         square 8x8        24         5376        300  300.377342  0.015769
# 1             tri 8x8        16         5152        300  300.584648  0.058859
# 9             tri 8x8        18          450        300  301.948649  0.163023
#
#      ergodic  wave_count
# 48  0.005466           9
# 45  0.003557           9
# 46  0.000356           9
# 47   0.00186          16
# 49  0.010397           9
# 50  0.000009           9
# 52  0.000156           9
# 53  0.005584           9
# 44  0.010414           9
# 16  0.010265          16
# 17  0.013417          16
# 41  0.000018           4
# 39  0.008003           9
# 40  0.012817          25
# 38  0.013165          16
# 34  0.001009          16
# 33  0.001009          16
# 7   0.000719          16
# 12  0.000719          16
# 13  0.000719          16
# 14  0.000719          16
# 15  0.000719          16
# 23  0.000719          16
# 22  0.000719          16
# 21  0.000719          16
# 25  0.000719          16
# 24  0.000719          16
# 32  0.000632          16
# 6   0.005164          16
# 36  0.000785          16
# 10  0.000347          16
# 11   0.00114          16
# 0   0.000569          16
# 8   0.002691          16
# 51  0.006257           9
# 54   0.00739           9
# 3   0.004019          16
# 2   0.004755          16
# 35  0.012399          16
# 30  0.012399          16
# 4   0.017432          16
# 18  0.017432          16
# 28  0.017432          16
# 19  0.017432          16
# 42       0.0           4
# 43  0.012002           9
# 20  0.017432          16
# 26  0.017432          16
# 29  0.017432          16
# 27  0.017432          16
# 31  0.008364          16
# 5   0.015069          16
# 37  0.000775          16
# 1   0.011287          16
# 9    0.00768          16

# %%
wave_df = df[(df['method']=='revisit-fix0-fix1') & (df['mesh']=='square 8x8') & (df['num_moves']==16) & (df['pdf'].isin(['cosine-ridges-2','uniform']))]
wave_df.sort_values(['pdf','mesh','num_moves','method','wave_count'])
# Out:
#                method            case
# 41  revisit-fix0-fix1  run_1723806205  \
# 39  revisit-fix0-fix1  run_1723805754
# 40  revisit-fix0-fix1  run_1723805849
# 42  revisit-fix0-fix1  run_1723806260
# 43  revisit-fix0-fix1  run_1723806289
# 20  revisit-fix0-fix1  run_1723801384
# 26  revisit-fix0-fix1  run_1723802008
# 29  revisit-fix0-fix1  run_1723802478
#
#                                          wave_numbers              pdf
# 41                   [[0, 0], [0, 1], [1, 0], [1, 1]]  cosine-ridges-2  \
# 39  [[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2...  cosine-ridges-2
# 40  [[0, 0], [0, 1], [0, 2], [0, 3], [0, 4], [1, 0...  cosine-ridges-2
# 42                   [[0, 0], [0, 1], [1, 0], [1, 1]]          uniform
# 43  [[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2...          uniform
# 20  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 26  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
# 29  [[0, 0], [0, 1], [0, 2], [0, 3], [1, 0], [1, 1...          uniform
#
#           mesh num_moves num_binaries time_limit  solve_time objective
# 41  square 8x8        16         3584        300    3.766991  0.002087  \
# 39  square 8x8        16         3584        300   34.921739  0.056485
# 40  square 8x8        16         3584        300  196.829248  0.082853
# 42  square 8x8        16         3584        300    9.747314       0.0
# 43  square 8x8        16         3584        300   63.351682  0.043093
# 20  square 8x8        16         3584        300   84.576104  0.043949
# 26  square 8x8        16         3584        300   88.233253  0.043949
# 29  square 8x8        16         3584        300   90.688772  0.043949
#
#      ergodic  wave_count
# 41  0.000018           4
# 39  0.008003           9
# 40  0.012817          25
# 42       0.0           4
# 43  0.012002           9
# 20  0.017432          16
# 26  0.017432          16
# 29  0.017432          16

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
wave_df.sort_values(['wave_count']).groupby('pdf').plot(x='wave_count',y='solve_time',ax=ax)
# Out:
# pdf
# cosine-ridges-2    Axes(0.125,0.11;0.775x0.77)
# uniform            Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
import glob

# %%
file_list = glob.glob('run_*.json')

# %%
fn = file_list[0]

# %%
import json

# %%
with open(fn,'r') as f:
    data_dict = json.load(f)

# %%
data_dict
# Out:
# {'method': 'revisit',
#  'case': 'run_1723635087',
#  'wave_numbers': [[0, 0],
#   [0, 1],
#   [0, 2],
#   [0, 3],
#   [1, 0],
#   [1, 1],
#   [1, 2],
#   [1, 3],
#   [2, 0],
#   [2, 1],
#   [2, 2],
#   [2, 3],
#   [3, 0],
#   [3, 1],
#   [3, 2],
#   [3, 3]],
#  'pdf': 'gaussian',
#  'mesh': 'tri 8x8',
#  'num_moves': 16,
#  'num_binaries': 5152,
#  'time_limit': 300,
#  'solve_time': 148.46816039085388,
#  'objective': 0.009080590765222812,
#  'ergodic': 0.0005693584963645422}

# %%
import pandas

# %%
df = pandas.DataFrame({})

# %%
df_new = pandas.DataFrame(data_dict)

# %%
df_new
# Out:
#      method            case wave_numbers       pdf     mesh  num_moves
# 0   revisit  run_1723635087       [0, 0]  gaussian  tri 8x8         16  \
# 1   revisit  run_1723635087       [0, 1]  gaussian  tri 8x8         16
# 2   revisit  run_1723635087       [0, 2]  gaussian  tri 8x8         16
# 3   revisit  run_1723635087       [0, 3]  gaussian  tri 8x8         16
# 4   revisit  run_1723635087       [1, 0]  gaussian  tri 8x8         16
# 5   revisit  run_1723635087       [1, 1]  gaussian  tri 8x8         16
# 6   revisit  run_1723635087       [1, 2]  gaussian  tri 8x8         16
# 7   revisit  run_1723635087       [1, 3]  gaussian  tri 8x8         16
# 8   revisit  run_1723635087       [2, 0]  gaussian  tri 8x8         16
# 9   revisit  run_1723635087       [2, 1]  gaussian  tri 8x8         16
# 10  revisit  run_1723635087       [2, 2]  gaussian  tri 8x8         16
# 11  revisit  run_1723635087       [2, 3]  gaussian  tri 8x8         16
# ...
